# %% [markdown]
# # <center>Clean And Analyze Employee Exit Surveys</center>

# %% [markdown]
# This project will be demonstrating data cleaning an analysis techniques through the analysis of employee exit surveys. The data used for analysis came from the [Department of Education, Training and Employment](https://en.wikipedia.org/wiki/Department_of_Education_and_Training_(Queensland) (DETE) and the Technical and Further Education (TAFE) institute in Queensland, Australia. Stakeholders can find the TAFE exit survey [here](https://data.gov.au/dataset/ds-qld-89970a3b-182b-41ea-aea2-6f9f17b5907e/details?q=exit%20survey) and the survey for the DETE [here](https://data.gov.au/dataset/ds-qld-89970a3b-182b-41ea-aea2-6f9f17b5907e/details?q=exit%20survey).

# %% [markdown]
# The following information will be presented to stakeholders:

# %% [markdown]
# * Are employees who only worked for the institutes for a short period of time resigning due to some kind dissatisfaction? What about employees who have been there longer?
#
# * Are younger employees resigning due to some kind of dissatisfaction? What about older employees?

# %% [markdown]
# Below is a preview of columns being used from the `dete_survey.csv`:

# %% [markdown]
# * `ID`: An id used to identify the participant of the survey
# * `SeperationType`: The reason why the person's employment ended
# * `Cease Date`: The year or month the person's employment ended
# * `DETE Start Date`: The year the person began employment with the DETE

# %% [markdown]
# Below is a preview of columns being used from the `tafe_survery.csv`:

# %% [markdown]
# * `Record ID`: An id used to identify the participant of the survey
# * `Reason for ceasing employment`: The reason why the person's employment ended
# * `LengthofServiceOverall..`: The length of the person's employment (in years)

# %% [markdown]
# ## Initial Data Exploration

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
dete_survey = pd.read_csv('dete_survey.csv')
tafe_survey = pd.read_csv('tafe_survey.csv')

# %%
dete_survey.head()
# Out:
#    ID                    SeparationType Cease Date DETE Start Date  \
# 0   1             Ill Health Retirement    08/2012            1984
# 1   2  Voluntary Early Retirement (VER)    08/2012      Not Stated
# 2   3  Voluntary Early Retirement (VER)    05/2012            2011
# 3   4         Resignation-Other reasons    05/2012            2005
# 4   5                    Age Retirement    05/2012            1970
#
#   Role Start Date                                      Position  \
# 0            2004                                Public Servant
# 1      Not Stated                                Public Servant
# 2            2011                               Schools Officer
# 3            2006                                       Teacher
# 4            1989  Head of Curriculum/Head of Special Education
#
#   Classification              Region                      Business Unit  \
# 0        A01-A04      Central Office  Corporate Strategy and Peformance
# ...

# %%
dete_survey.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 822 entries, 0 to 821
# Data columns (total 56 columns):
# ID                                     822 non-null int64
# SeparationType                         822 non-null object
# Cease Date                             822 non-null object
# DETE Start Date                        822 non-null object
# Role Start Date                        822 non-null object
# Position                               817 non-null object
# Classification                         455 non-null object
# Region                                 822 non-null object
# Business Unit                          126 non-null object
# Employment Status                      817 non-null object
# Career move to public sector           822 non-null bool
# Career move to private sector          822 non-null bool
# Interpersonal conflicts                822 non-null bool
# Job dissatisfaction                    822 non-null bool
# ...

# %%
dete_survey['Career move to public sector'].head()
# Out:
# 0     True
# 1    False
# 2    False
# 3    False
# 4    False
# Name: Career move to public sector, dtype: bool

# %%
dete_survey.isnull().sum()
# Out:
# ID                                       0
# SeparationType                           0
# Cease Date                               0
# DETE Start Date                          0
# Role Start Date                          0
# Position                                 5
# Classification                         367
# Region                                   0
# Business Unit                          696
# Employment Status                        5
# Career move to public sector             0
# Career move to private sector            0
# Interpersonal conflicts                  0
# Job dissatisfaction                      0
# Dissatisfaction with the department      0
# Physical work environment                0
# Lack of recognition                      0
# Lack of job security                     0
# Work location                            0
# Employment conditions                    0
# Maternity/family                         0
# Relocation                               0
# ...

# %% [markdown]
# ### Visualizing Missing Data

# %%
sns.heatmap(dete_survey.isnull(), cbar = False)

# %%
len(dete_survey.columns)
# Out:
# 56

# %% [markdown]
# Initial exploration shows that the `dete_survey` is made up of 56 columns consisting of different employment characteristics. Most of the data is presenting in either boolean or string forms. There is a small portion of the dataset that is missing for some columns mainly the `Classification`, `Business Unit`, `Torres Strait` and `Disability` columns. Some missing values contain a 'Not Stated' value instead of `NaN`.

# %%
tafe_survey.head()
# Out:
#       Record ID                              Institute  \
# 0  6.341330e+17  Southern Queensland Institute of TAFE
# 1  6.341337e+17            Mount Isa Institute of TAFE
# 2  6.341388e+17            Mount Isa Institute of TAFE
# 3  6.341399e+17            Mount Isa Institute of TAFE
# 4  6.341466e+17  Southern Queensland Institute of TAFE
#
#                    WorkArea  CESSATION YEAR Reason for ceasing employment  \
# 0  Non-Delivery (corporate)          2010.0              Contract Expired
# 1  Non-Delivery (corporate)          2010.0                    Retirement
# 2       Delivery (teaching)          2010.0                    Retirement
# 3  Non-Delivery (corporate)          2010.0                   Resignation
# 4       Delivery (teaching)          2010.0                   Resignation
#
#   Contributing Factors. Career Move - Public Sector   \
# 0                                                NaN
# 1                                                  -
# ...

# %%
tafe_survey.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 702 entries, 0 to 701
# Data columns (total 72 columns):
# Record ID                                                                                                                                                        702 non-null float64
# Institute                                                                                                                                                        702 non-null object
# WorkArea                                                                                                                                                         702 non-null object
# CESSATION YEAR                                                                                                                                                   695 non-null float64
# ...

# %%
tafe_survey.isnull().sum()
# Out:
# Record ID                                                                                                                                                          0
# Institute                                                                                                                                                          0
# WorkArea                                                                                                                                                           0
# CESSATION YEAR                                                                                                                                                     7
# Reason for ceasing employment                                                                                                                                      1
# ...

# %%
sns.heatmap(tafe_survey.isnull(), cbar = False)

# %% [markdown]
# Initial exploration of the `tafe_survey` dataset show a higher distribution of missing values. Columns that are similar to the `dete_survey` with different names. As well as several columns that are unnecessary for the main analysis goals.

# %% [markdown]
# ## Identifying Missing Values and Dropping Unnecessary Columns

# %% [markdown]
# Data cleaning tasks:

# %% [markdown]
# * The `dete_survey` dataframe contains `Not Stated` values that indicate values are missing, but they aren't represented as `NaN`.
# * Both the `dete_survey` and `tafe_survey` dataframes contain many columns that are unnecessary to complete the analysis.

# %% [markdown]
# Changing `Not Stated` values to `Nan`:

# %%
dete_survey = pd.read_csv('dete_survey.csv', na_values='Not Stated')

# %%
dete_survey.head()
# Out:
#    ID                    SeparationType Cease Date  DETE Start Date  \
# 0   1             Ill Health Retirement    08/2012           1984.0
# 1   2  Voluntary Early Retirement (VER)    08/2012              NaN
# 2   3  Voluntary Early Retirement (VER)    05/2012           2011.0
# 3   4         Resignation-Other reasons    05/2012           2005.0
# 4   5                    Age Retirement    05/2012           1970.0
#
#    Role Start Date                                      Position  \
# 0           2004.0                                Public Servant
# 1              NaN                                Public Servant
# 2           2011.0                               Schools Officer
# 3           2006.0                                       Teacher
# 4           1989.0  Head of Curriculum/Head of Special Education
#
#   Classification              Region                      Business Unit  \
# 0        A01-A04      Central Office  Corporate Strategy and Peformance
# ...

# %% [markdown]
# Removing unnecessary columns from the `dete_survey` dataframe:

# %%
drop_columns = list(dete_survey.columns[28:49])

# %%
drop_columns
# Out:
# ['Professional Development',
#  'Opportunities for promotion',
#  'Staff morale',
#  'Workplace issue',
#  'Physical environment',
#  'Worklife balance',
#  'Stress and pressure support',
#  'Performance of supervisor',
#  'Peer support',
#  'Initiative',
#  'Skills',
#  'Coach',
#  'Career Aspirations',
#  'Feedback',
#  'Further PD',
#  'Communication',
#  'My say',
#  'Information',
#  'Kept informed',
#  'Wellness programs',
#  'Health & Safety']

# %%
dete_survey_updated = dete_survey.drop(drop_columns, axis = 1)

# %%
dete_survey_updated.head()
# Out:
#    ID                    SeparationType Cease Date  DETE Start Date  \
# 0   1             Ill Health Retirement    08/2012           1984.0
# 1   2  Voluntary Early Retirement (VER)    08/2012              NaN
# 2   3  Voluntary Early Retirement (VER)    05/2012           2011.0
# 3   4         Resignation-Other reasons    05/2012           2005.0
# 4   5                    Age Retirement    05/2012           1970.0
#
#    Role Start Date                                      Position  \
# 0           2004.0                                Public Servant
# 1              NaN                                Public Servant
# 2           2011.0                               Schools Officer
# 3           2006.0                                       Teacher
# 4           1989.0  Head of Curriculum/Head of Special Education
#
#   Classification              Region                      Business Unit  \
# 0        A01-A04      Central Office  Corporate Strategy and Peformance
# ...

# %% [markdown]
# Removing unnecessary columns from the `tate_survey` dataframe:

# %%
tafe_drop_columns = tafe_survey.columns[17:66]

# %%
tafe_survey_updated = tafe_survey.drop(tafe_drop_columns, axis = 1)

# %%
tafe_survey_updated.head()
# Out:
#       Record ID                              Institute  \
# 0  6.341330e+17  Southern Queensland Institute of TAFE
# 1  6.341337e+17            Mount Isa Institute of TAFE
# 2  6.341388e+17            Mount Isa Institute of TAFE
# 3  6.341399e+17            Mount Isa Institute of TAFE
# 4  6.341466e+17  Southern Queensland Institute of TAFE
#
#                    WorkArea  CESSATION YEAR Reason for ceasing employment  \
# 0  Non-Delivery (corporate)          2010.0              Contract Expired
# 1  Non-Delivery (corporate)          2010.0                    Retirement
# 2       Delivery (teaching)          2010.0                    Retirement
# 3  Non-Delivery (corporate)          2010.0                   Resignation
# 4       Delivery (teaching)          2010.0                   Resignation
#
#   Contributing Factors. Career Move - Public Sector   \
# 0                                                NaN
# 1                                                  -
# ...

# %% [markdown]
# ## Cleaning Column Names

# %% [markdown]
# Each dataframe contains many of the same columns, but the column names are different. Below are some of the columns that will be useful to the final analysis:

# %% [markdown]
# <table class="tg">
# <tbody><tr>
# <th>dete_survey<br></th>
# <th>tafe_survey</th>
# <th>Definition</th>
# </tr>
# <tr>
# <td>ID</td>
# <td>Record ID</td>
# <td>An id used to identify the participant of the survey</td>
# </tr>
# <tr>
# <td>SeparationType</td>
# <td>Reason for ceasing <br>employment<br></td>
# <td>The reason why the participant's employment ended</td>
# </tr>
# <tr>
# <td>Cease Date</td>
# <td>CESSATION YEAR</td>
# <td>The year or month the participant's employment ended</td>
# </tr>
# <tr>
# <td>DETE Start Date</td>
# <td></td>
# <td>The year the participant began employment with the DETE</td>
# </tr>
# <tr>
# <td></td>
# <td>LengthofServiceOverall. <br>Overall Length of Service <br>at Institute (in years)<br><br></td>
# <td>The length of the person's employment (in years)</td>
# </tr>
# <tr>
# <td>Age</td>
# <td>CurrentAge. <br>Current Age<br></td>
# <td>The age of the participant</td>
# </tr>
# <tr>
# <td>Gender</td>
# <td>Gender. <br>What is your Gender?<br></td>
# <td>The gender of the participant</td>
# </tr>
# </tbody></table>

# %% [markdown]
# In order to combine data for analysis all column names will be standardized.

# %% [markdown]
# Updating `dete_survey` column names:

# %%
dete_survey_updated.columns
# Out:
# Index(['ID', 'SeparationType', 'Cease Date', 'DETE Start Date',
#        'Role Start Date', 'Position', 'Classification', 'Region',
#        'Business Unit', 'Employment Status', 'Career move to public sector',
#        'Career move to private sector', 'Interpersonal conflicts',
#        'Job dissatisfaction', 'Dissatisfaction with the department',
#        'Physical work environment', 'Lack of recognition',
#        'Lack of job security', 'Work location', 'Employment conditions',
#        'Maternity/family', 'Relocation', 'Study/Travel', 'Ill Health',
#        'Traumatic incident', 'Work life balance', 'Workload',
#        'None of the above', 'Gender', 'Age', 'Aboriginal', 'Torres Strait',
#        'South Sea', 'Disability', 'NESB'],
#       dtype='object')

# %%
dete_survey_updated.columns = dete_survey_updated.columns.str.replace(' ', '_').str.strip().str.lower()

# %%
dete_survey_updated.columns
# Out:
# Index(['id', 'separationtype', 'cease_date', 'dete_start_date',
#        'role_start_date', 'position', 'classification', 'region',
#        'business_unit', 'employment_status', 'career_move_to_public_sector',
#        'career_move_to_private_sector', 'interpersonal_conflicts',
#        'job_dissatisfaction', 'dissatisfaction_with_the_department',
#        'physical_work_environment', 'lack_of_recognition',
#        'lack_of_job_security', 'work_location', 'employment_conditions',
#        'maternity/family', 'relocation', 'study/travel', 'ill_health',
#        'traumatic_incident', 'work_life_balance', 'workload',
#        'none_of_the_above', 'gender', 'age', 'aboriginal', 'torres_strait',
#        'south_sea', 'disability', 'nesb'],
#       dtype='object')

# %% [markdown]
# Updating `tafe_survey` column names:

# %%
new_tafe_column_names = {'Record ID': 'id', 'CESSATION YEAR': 'cease_date', 
                        'Reason for ceasing employment': 'separationtype', 
                         'Gender. What is your Gender?': 'gender',
                        'CurrentAge. Current Age': 'age', 
                        'Employment Type. Employment Type': 'employment_status',
                        'Classification. Classification': 'position', 
                        'LengthofServiceOverall. Overall Length of Service at Institute (in years)': 'institute_service',
                        'LengthofServiceCurrent. Length of Service at current workplace (in years)': 'role_service'}

# %%
tafe_survey_updated = tafe_survey_updated.rename(index = str, columns = new_tafe_column_names)

# %%
tafe_survey_updated.head()
# Out:
#              id                              Institute  \
# 0  6.341330e+17  Southern Queensland Institute of TAFE
# 1  6.341337e+17            Mount Isa Institute of TAFE
# 2  6.341388e+17            Mount Isa Institute of TAFE
# 3  6.341399e+17            Mount Isa Institute of TAFE
# 4  6.341466e+17  Southern Queensland Institute of TAFE
#
#                    WorkArea  cease_date    separationtype  \
# 0  Non-Delivery (corporate)      2010.0  Contract Expired
# 1  Non-Delivery (corporate)      2010.0        Retirement
# 2       Delivery (teaching)      2010.0        Retirement
# 3  Non-Delivery (corporate)      2010.0       Resignation
# 4       Delivery (teaching)      2010.0       Resignation
#
#   Contributing Factors. Career Move - Public Sector   \
# 0                                                NaN
# 1                                                  -
# 2                                                  -
# 3                                                  -
# ...

# %%
dete_survey_updated.head()
# Out:
#    id                    separationtype cease_date  dete_start_date  \
# 0   1             Ill Health Retirement    08/2012           1984.0
# 1   2  Voluntary Early Retirement (VER)    08/2012              NaN
# 2   3  Voluntary Early Retirement (VER)    05/2012           2011.0
# 3   4         Resignation-Other reasons    05/2012           2005.0
# 4   5                    Age Retirement    05/2012           1970.0
#
#    role_start_date                                      position  \
# 0           2004.0                                Public Servant
# 1              NaN                                Public Servant
# 2           2011.0                               Schools Officer
# 3           2006.0                                       Teacher
# 4           1989.0  Head of Curriculum/Head of Special Education
#
#   classification              region                      business_unit  \
# 0        A01-A04      Central Office  Corporate Strategy and Peformance
# ...

# %% [markdown]
# ## Filtering the Data

# %% [markdown]
# After renaming many of the column names further filtering the the dataset is necessary to narrow down analysis and achieve the main goal.
#
# Recall the end goal of this project is to answer the following question:
#
# * Are employees who have only worked for the institutes for a short period of time resigning due to some kind of dissatisfaction? What about employees who have been at the job longer?
#
# Looking at the unique values in the `separationtype` column in each dataframe shows that each contains a couple of different separation types. To achieve the main goal of this project analysis will only be done on survey responses with the `Resignation` in their `separationtype`.

# %%
dete_survey_updated['separationtype'].value_counts()
# Out:
# Age Retirement                          285
# Resignation-Other reasons               150
# Resignation-Other employer               91
# Resignation-Move overseas/interstate     70
# Voluntary Early Retirement (VER)         67
# Ill Health Retirement                    61
# Other                                    49
# Contract Expired                         34
# Termination                              15
# Name: separationtype, dtype: int64

# %%
tafe_survey_updated['separationtype'].value_counts()
# Out:
# Resignation                 340
# Contract Expired            127
# Retrenchment/ Redundancy    104
# Retirement                   82
# Transfer                     25
# Termination                  23
# Name: separationtype, dtype: int64

# %% [markdown]
# Setting `dete_survey` filter:

# %%
criteria_1 = dete_survey_updated['separationtype'] == 'Resignation-Other reasons'
criteria_2 = dete_survey_updated['separationtype'] == 'Resignation-Other employer'
criteria_3 = dete_survey_updated['separationtype'] == 'Resignation-Move overseas/interstate'

criteria_all = criteria_1 | criteria_2 | criteria_3

# %%
dete_resignations = dete_survey_updated[criteria_all].copy()

# %%
len(dete_resignations)
# Out:
# 311

# %%
tafe_resignations = tafe_survey_updated[tafe_survey_updated['separationtype']=='Resignation']

# %%
len(tafe_resignations)
# Out:
# 340

# %% [markdown]
# ## Verifying the Data

# %% [markdown]
# This step will be used to verify the validity of the data. It is necessary to make sure the data being used for analysis isn't corrupted in some way.
#
# The focus for the purposes of this analysis will be on verifying the years in the `cease_date` and `dete_start_date` columns correctly reflect what is expected for this dataset.

# %% [markdown]
# * Since the `cease_date` is the last year of the person's employment and the `dete_start_date` is the person's first year of employment it wouldn't make sense to have years after the current date.
# * Given that most people in this field start working in their 20's, it's also unlikely that the `dete_start_date` was before the year 1940.

# %% [markdown]
# If there are many responses with years higher than the current date or lower than 1940, analysis for the purpose this project would not be valid. If there are a small amount of values that are unrealistically high or low, they will be removed.

# %% [markdown]
# Checking years in the dataframe for logical inconsistencies:

# %%
dete_resignations['cease_date'].value_counts()
# Out:
# 2012       126
# 2013        74
# 01/2014     22
# 12/2013     17
# 06/2013     14
# 09/2013     11
# 07/2013      9
# 11/2013      9
# 10/2013      6
# 08/2013      4
# 05/2013      2
# 05/2012      2
# 07/2006      1
# 2010         1
# 09/2010      1
# 07/2012      1
# Name: cease_date, dtype: int64

# %% [markdown]
# ### Cleaning Date Data

# %%
pattern = r"(?P<Years>[1-2][0-9]{3})"
cease_date_years = dete_resignations['cease_date'].str.extract(pattern)

# %%
cease_date_years.head()
# Out:
#    Years
# 3   2012
# 5   2012
# 8   2012
# 9   2012
# 11  2012

# %%
cease_date_years = cease_date_years.astype('float')

# %%
dete_resignations['cease_date'] = cease_date_years

# %%
dete_resignations['dete_start_date'].value_counts()
# Out:
# 2011.0    24
# 2008.0    22
# 2007.0    21
# 2012.0    21
# 2010.0    17
# 2005.0    15
# 2004.0    14
# 2009.0    13
# 2006.0    13
# 2013.0    10
# 2000.0     9
# 1999.0     8
# 1996.0     6
# 2002.0     6
# 1992.0     6
# 1998.0     6
# 2003.0     6
# 1994.0     6
# 1993.0     5
# 1990.0     5
# 1980.0     5
# 1997.0     5
# 1991.0     4
# 1989.0     4
# 1988.0     4
# 1995.0     4
# 2001.0     3
# 1985.0     3
# 1986.0     3
# 1983.0     2
# 1976.0     2
# 1974.0     2
# 1971.0     1
# 1972.0     1
# 1984.0     1
# 1982.0     1
# 1987.0     1
# 1975.0     1
# 1973.0     1
# 1977.0     1
# 1963.0     1
# Name: dete_start_date, dtype: int64

# %%
tafe_resignations['cease_date'].value_counts().sort_index()
# Out:
# 2009.0      2
# 2010.0     68
# 2011.0    116
# 2012.0     94
# 2013.0     55
# Name: cease_date, dtype: int64

# %%
tafe_resignations.boxplot(column='cease_date')

# %%
dete_resignations.boxplot(column=['dete_start_date'])

# %%
dete_resignations.boxplot(column=['cease_date'])

# %% [markdown]
# From the above data we can verify:
# 1. There aren't any major issues with the years.
# 2. The years in each dataframe don't span quite the same number of years.

# %% [markdown]
# ## Creating New Columns

# %% [markdown]
# In the Human resources field, the length of time an employee spent in a workplace is referred to as their years of service.
#
# The `tafe_resignations` dataframe already contains a "service" column that was renamed to `intitute_service`. In order to analyze both surveys together a new corresponding `institute_service` column will be created in `dete_resignations`.

# %%
tafe_resignations.head()
# Out:
#              id                              Institute  \
# 3  6.341399e+17            Mount Isa Institute of TAFE
# 4  6.341466e+17  Southern Queensland Institute of TAFE
# 5  6.341475e+17  Southern Queensland Institute of TAFE
# 6  6.341520e+17         Barrier Reef Institute of TAFE
# 7  6.341537e+17  Southern Queensland Institute of TAFE
#
#                    WorkArea  cease_date separationtype  \
# 3  Non-Delivery (corporate)      2010.0    Resignation
# 4       Delivery (teaching)      2010.0    Resignation
# 5       Delivery (teaching)      2010.0    Resignation
# 6  Non-Delivery (corporate)      2010.0    Resignation
# 7       Delivery (teaching)      2010.0    Resignation
#
#   Contributing Factors. Career Move - Public Sector   \
# 3                                                  -
# 4                                                  -
# 5                                                  -
# 6                                                  -
# ...

# %%
dete_resignations.head()
# Out:
#     id                        separationtype  cease_date  dete_start_date  \
# 3    4             Resignation-Other reasons      2012.0           2005.0
# 5    6             Resignation-Other reasons      2012.0           1994.0
# 8    9             Resignation-Other reasons      2012.0           2009.0
# 9   10            Resignation-Other employer      2012.0           1997.0
# 11  12  Resignation-Move overseas/interstate      2012.0           2009.0
#
#     role_start_date          position classification                region  \
# 3            2006.0           Teacher        Primary    Central Queensland
# 5            1997.0  Guidance Officer            NaN        Central Office
# 8            2009.0           Teacher      Secondary      North Queensland
# 9            2008.0      Teacher Aide            NaN                   NaN
# 11           2009.0           Teacher      Secondary  Far North Queensland
#
# ...

# %%
dete_resignations['institute_service'] = dete_resignations['cease_date']-dete_resignations['dete_start_date']

# %%
dete_resignations['institute_service'].value_counts()
# Out:
# 5.0     23
# 1.0     22
# 3.0     20
# 0.0     20
# 6.0     17
# 4.0     16
# 9.0     14
# 2.0     14
# 7.0     13
# 13.0     8
# 8.0      8
# 20.0     7
# 15.0     7
# 10.0     6
# 22.0     6
# 14.0     6
# 17.0     6
# 12.0     6
# 16.0     5
# 18.0     5
# 23.0     4
# 11.0     4
# 24.0     4
# 39.0     3
# 19.0     3
# 21.0     3
# 32.0     3
# 28.0     2
# 26.0     2
# 25.0     2
# 30.0     2
# 36.0     2
# 29.0     1
# 33.0     1
# 42.0     1
# 27.0     1
# 41.0     1
# 35.0     1
# 38.0     1
# 34.0     1
# 49.0     1
# 31.0     1
# Name: institute_service, dtype: int64

# %%
tafe_resignations['institute_service'].value_counts()
# Out:
# Less than 1 year      73
# 1-2                   64
# 3-4                   63
# 5-6                   33
# 11-20                 26
# 7-10                  21
# More than 20 years    10
# Name: institute_service, dtype: int64

# %% [markdown]
# ## Identifying Dissatisfied Employees

# %% [markdown]
# The clean dataset will be used to identify any employees who resigned because they were dissatisfied.
#
# Below are the columns used to categorize employees as "dissatisfied" from each dataframe.

# %% [markdown]
# 1. <b>tafe_resignations</b>:
#     * `Contributing Factors. Dissatisfaction`
#     * `Contributing Factors. Job Dissatisfaction`

# %% [markdown]
# 2. <b>dete_resignations</b>:
#     * `job_dissatisfaction`
#     * `dissatisfaction_with_the_department`
#     * `physical_work_environment`
#     * `lack_of_recognition`
#     * `lack_of_job_security`
#     * `work_location`
#     * `employment_conditions`
#     * `work_life_balance`
#     * `workload`

# %% [markdown]
# If an employee indicated any of the factors above caused them to resign, they will be marked as `dissatisfied` in a new column.

# %%
tafe_resignations['Contributing Factors. Dissatisfaction'].value_counts()
# Out:
# -                                         277
# Contributing Factors. Dissatisfaction      55
# Name: Contributing Factors. Dissatisfaction, dtype: int64

# %%
tafe_resignations['Contributing Factors. Dissatisfaction'].isnull().sum()
# Out:
# 8

# %%
tafe_resignations['Contributing Factors. Job Dissatisfaction'].value_counts()
# Out:
# -                      270
# Job Dissatisfaction     62
# Name: Contributing Factors. Job Dissatisfaction, dtype: int64

# %%
tafe_resignations['Contributing Factors. Job Dissatisfaction'].isnull().sum()
# Out:
# 8

# %%
def update_vals(val):
    if pd.isnull(val):
        return np.nan
    elif val == '-':
        return False
    else:
        return True

# %%
tafe_resignations.columns
# Out:
# Index(['id', 'Institute', 'WorkArea', 'cease_date', 'separationtype',
#        'Contributing Factors. Career Move - Public Sector ',
#        'Contributing Factors. Career Move - Private Sector ',
#        'Contributing Factors. Career Move - Self-employment',
#        'Contributing Factors. Ill Health',
#        'Contributing Factors. Maternity/Family',
#        'Contributing Factors. Dissatisfaction',
#        'Contributing Factors. Job Dissatisfaction',
#        'Contributing Factors. Interpersonal Conflict',
#        'Contributing Factors. Study', 'Contributing Factors. Travel',
#        'Contributing Factors. Other', 'Contributing Factors. NONE', 'gender',
#        'age', 'employment_status', 'position', 'institute_service',
#        'role_service'],
#       dtype='object')

# %%
tafe_resignations.loc[:,'Contributing Factors. Dissatisfaction':'Contributing Factors. Job Dissatisfaction'].head(15)
# Out:
#      Contributing Factors. Dissatisfaction  \
# 3                                        -
# 4                                        -
# 5                                        -
# 6                                        -
# 7                                        -
# 8                                        -
# 9                                        -
# 10                                       -
# 13                                       -
# 14  Contributing Factors. Dissatisfaction
# 15                                       -
# 16                                     NaN
# 17                                       -
# 18                                     NaN
# 19                                       -
#
#    Contributing Factors. Job Dissatisfaction
# 3                                          -
# 4                                          -
# 5                                          -
# 6                                          -
# ...

# %%
tafe_resignations.loc[:,'Contributing Factors. Dissatisfaction':'Contributing Factors. Job Dissatisfaction'] = tafe_resignations.loc[:,
'Contributing Factors. Dissatisfaction':'Contributing Factors. Job Dissatisfaction'].applymap(update_vals)

# %%
tafe_resignations.loc[:,'Contributing Factors. Dissatisfaction':'Contributing Factors. Job Dissatisfaction'].head(15)
# Out:
#    Contributing Factors. Dissatisfaction  \
# 3                                  False
# 4                                  False
# 5                                  False
# 6                                  False
# 7                                  False
# 8                                  False
# 9                                  False
# 10                                 False
# 13                                 False
# 14                                  True
# 15                                 False
# 16                                   NaN
# 17                                 False
# 18                                   NaN
# 19                                 False
#
#    Contributing Factors. Job Dissatisfaction
# 3                                      False
# 4                                      False
# 5                                      False
# 6                                      False
# 7                                      False
# ...

# %%
tafe_columns = ['Contributing Factors. Dissatisfaction',
                'Contributing Factors. Job Dissatisfaction']
dete_columns = ['job_dissatisfaction', 'dissatisfaction_with_the_department',
               'physical_work_environment', 'lack_of_recognition','lack_of_job_security',
               'work_location','employment_conditions','work_life_balance',
               'workload']

# %%
tafe_resignations['dissatisfied'] = tafe_resignations[tafe_columns].any(axis=1, skipna=False)

# %%
tafe_resignations.head()
# Out:
#              id                              Institute  \
# 3  6.341399e+17            Mount Isa Institute of TAFE
# 4  6.341466e+17  Southern Queensland Institute of TAFE
# 5  6.341475e+17  Southern Queensland Institute of TAFE
# 6  6.341520e+17         Barrier Reef Institute of TAFE
# 7  6.341537e+17  Southern Queensland Institute of TAFE
#
#                    WorkArea  cease_date separationtype  \
# 3  Non-Delivery (corporate)      2010.0    Resignation
# 4       Delivery (teaching)      2010.0    Resignation
# 5       Delivery (teaching)      2010.0    Resignation
# 6  Non-Delivery (corporate)      2010.0    Resignation
# 7       Delivery (teaching)      2010.0    Resignation
#
#   Contributing Factors. Career Move - Public Sector   \
# 3                                                  -
# 4                                                  -
# 5                                                  -
# 6                                                  -
# ...

# %%
dete_resignations['dissatisfied'] = dete_resignations[dete_columns].any(axis = 1, skipna=False)

# %%
dete_resignations.head()
# Out:
#     id                        separationtype  cease_date  dete_start_date  \
# 3    4             Resignation-Other reasons      2012.0           2005.0
# 5    6             Resignation-Other reasons      2012.0           1994.0
# 8    9             Resignation-Other reasons      2012.0           2009.0
# 9   10            Resignation-Other employer      2012.0           1997.0
# 11  12  Resignation-Move overseas/interstate      2012.0           2009.0
#
#     role_start_date          position classification                region  \
# 3            2006.0           Teacher        Primary    Central Queensland
# 5            1997.0  Guidance Officer            NaN        Central Office
# 8            2009.0           Teacher      Secondary      North Queensland
# 9            2008.0      Teacher Aide            NaN                   NaN
# 11           2009.0           Teacher      Secondary  Far North Queensland
#
#            business_unit    employment_status      ...       \
# ...

# %% [markdown]
# ## Combining the Data

# %% [markdown]
# An aggregation will be done on the dataset with the institute_service column to complete the final analysis. To allow for easy aggregation the data will be combined using the `pd.concat` function. Before combining the data each dataframe will have a institute column added to distinguish between the two.

# %%
tafe_resignations['institute'] = 'TAFE'

# %%
dete_resignations['institute'] = 'DETE'

# %%
combined = pd.concat([tafe_resignations, dete_resignations])

# %%
combined.head()
# Out:
#   Contributing Factors. Career Move - Private Sector   \
# 3                                                  -
# 4                       Career Move - Private Sector
# 5                                                  -
# 6                       Career Move - Private Sector
# 7                                                  -
#
#   Contributing Factors. Career Move - Public Sector   \
# 3                                                  -
# 4                                                  -
# 5                                                  -
# 6                                                  -
# 7                                                  -
#
#   Contributing Factors. Career Move - Self-employment  \
# 3                                                  -
# 4                                                  -
# 5                                                  -
# 6                                                  -
# ...

# %% [markdown]
# ##### Dropping Unnecessary Columns

# %%
combined_updated = combined.dropna(axis=1, thresh = 200)

# %%
combined_updated.head()
# Out:
#   Contributing Factors. Career Move - Private Sector   \
# 3                                                  -
# 4                       Career Move - Private Sector
# 5                                                  -
# 6                       Career Move - Private Sector
# 7                                                  -
#
#   Contributing Factors. Career Move - Public Sector   \
# 3                                                  -
# 4                                                  -
# 5                                                  -
# 6                                                  -
# 7                                                  -
#
#   Contributing Factors. Career Move - Self-employment  \
# 3                                                  -
# 4                                                  -
# 5                                                  -
# 6                                                  -
# ...

# %% [markdown]
# ## Cleaning the Service Column

# %% [markdown]
# To allow for correct analysis of the years of service the `institute service` column needs to be cleaned. The column currently contains values in a couple of different forms:

# %% [markdown]
# <div class="CodeMirror-code" role="presentation" style=""><pre class=" CodeMirror-line " role="presentation"><span role="presentation" style="padding-right: 0.1px;"><span class="cm-variable">NaN</span> &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; <span class="cm-number">164</span></span></pre><pre class=" CodeMirror-line " role="presentation"><span role="presentation" style="padding-right: 0.1px;"><span class="cm-variable">Less</span> <span class="cm-variable">than</span> <span class="cm-number">1</span> <span class="cm-variable">year</span> &nbsp; &nbsp; &nbsp; <span class="cm-number">77</span></span></pre><pre class=" CodeMirror-line " role="presentation"><span role="presentation" style="padding-right: 0.1px;"><span class="cm-number">3</span><span class="cm-operator">-</span><span class="cm-number">4</span> &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp;<span class="cm-number">72</span></span></pre><pre class=" CodeMirror-line " role="presentation"><span role="presentation" style="padding-right: 0.1px;"><span class="cm-number">1</span><span class="cm-operator">-</span><span class="cm-number">2</span> &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp;<span class="cm-number">68</span></span></pre><pre class=" CodeMirror-line " role="presentation"><span role="presentation" style="padding-right: 0.1px;"><span class="cm-number">11</span><span class="cm-operator">-</span><span class="cm-number">20</span> &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp;<span class="cm-number">49</span></span></pre><pre class=" CodeMirror-line " role="presentation"><span role="presentation" style="padding-right: 0.1px;"><span class="cm-variable">More</span> <span class="cm-variable">than</span> <span class="cm-number">20</span> <span class="cm-variable">years</span> &nbsp; &nbsp; <span class="cm-number">48</span></span></pre><pre class=" CodeMirror-line " role="presentation"><span role="presentation" style="padding-right: 0.1px;"><span class="cm-number">5</span><span class="cm-operator">-</span><span class="cm-number">6</span> &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp;<span class="cm-number">36</span></span></pre><pre class=" CodeMirror-line " role="presentation"><span role="presentation" style="padding-right: 0.1px;"><span class="cm-number">7</span><span class="cm-operator">-</span><span class="cm-number">10</span> &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; <span class="cm-number">30</span></span></pre><pre class=" CodeMirror-line " role="presentation"><span role="presentation" style="padding-right: 0.1px;"><span class="cm-number">5.0</span> &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp;<span class="cm-number">30</span></span></pre><pre class=" CodeMirror-line " role="presentation"><span role="presentation" style="padding-right: 0.1px;"><span class="cm-number">3.0</span> &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp;<span class="cm-number">28</span></span></pre></div>

# %% [markdown]
# To analyze the date, the numbers will be converted into categories. This analysis is based on a [Businesswire](https://www.businesswire.com/news/home/20171108006002/en/Age-Number-Engage-Employees-Career-Stage), which makes the argument that understanding employee's needs according to career stage instead of age is more effective.

# %% [markdown]
# The categories selected are listed are list below:
# * New: less than 3 years at a company
# * Experienced: 3-6 years at a company
# * Established: 7-10 years at a company
# * Veteran: 11 or more years at a company

# %%
combined_updated['institute_service']
# Out:
# 3                     NaN
# 4                     3-4
# 5                    7-10
# 6                     3-4
# 7                     3-4
# 8                     3-4
# 9                     1-2
# 10       Less than 1 year
# 13                  11-20
# 14                   7-10
# 15                  11-20
# 16                    NaN
# 17                   7-10
# 18                    NaN
# 19                    NaN
# 20                    NaN
# 21                    NaN
# 22                    5-6
# 23       Less than 1 year
# 24                   7-10
# 26                    NaN
# 27     More than 20 years
# 29       Less than 1 year
# 32       Less than 1 year
# 36                    NaN
# 37                    NaN
# 39                    NaN
# 40       Less than 1 year
# 41                  11-20
# 42                    3-4
#               ...
# 747                     6
# 751                     8
# 752                    15
# 753                     9
# 755                     1
# ...

# %% [markdown]
# #### Extracting the years of service form each value in the `institute service` column:

# %%
test = combined_updated['institute_service'].astype('str')

# %%
test = test.str.replace('-','.')

# %%
# Out:
# 3                     nan
# 4                     3.4
# 5                    7.10
# 6                     3.4
# 7                     3.4
# 8                     3.4
# 9                     1.2
# 10       Less than 1 year
# 13                  11.20
# 14                   7.10
# 15                  11.20
# 16                    nan
# 17                   7.10
# 18                    nan
# 19                    nan
# 20                    nan
# 21                    nan
# 22                    5.6
# 23       Less than 1 year
# 24                   7.10
# 26                    nan
# 27     More than 20 years
# 29       Less than 1 year
# 32       Less than 1 year
# 36                    nan
# 37                    nan
# 39                    nan
# 40       Less than 1 year
# 41                  11.20
# 42                    3.4
#               ...
# 747                   6.0
# 751                   8.0
# 752                  15.0
# 753                   9.0
# 755                   1.0
# ...

# %%
test = test.str.replace(' ', '.')

# %%
test
# Out:
# 3                     nan
# 4                     3.4
# 5                    7.10
# 6                     3.4
# 7                     3.4
# 8                     3.4
# 9                     1.2
# 10       Less.than.1.year
# 13                  11.20
# 14                   7.10
# 15                  11.20
# 16                    nan
# 17                   7.10
# 18                    nan
# 19                    nan
# 20                    nan
# 21                    nan
# 22                    5.6
# 23       Less.than.1.year
# 24                   7.10
# 26                    nan
# 27     More.than.20.years
# 29       Less.than.1.year
# 32       Less.than.1.year
# 36                    nan
# 37                    nan
# 39                    nan
# 40       Less.than.1.year
# 41                  11.20
# 42                    3.4
#               ...
# 747                   6.0
# 751                   8.0
# 752                  15.0
# 753                   9.0
# 755                   1.0
# ...

# %%
pattern = r"([0-9]+\.[0-9]?)"

# %%
extracted = test.str.extract(pattern, expand = True)

# %%
extracted = extracted.astype('float')

# %%
extracted
# Out:
#         0
# 3     NaN
# 4     3.4
# 5     7.1
# 6     3.4
# 7     3.4
# 8     3.4
# 9     1.2
# 10    1.0
# 13   11.2
# 14    7.1
# 15   11.2
# 16    NaN
# 17    7.1
# 18    NaN
# 19    NaN
# 20    NaN
# 21    NaN
# 22    5.6
# 23    1.0
# 24    7.1
# 26    NaN
# 27   20.0
# 29    1.0
# 32    1.0
# 36    NaN
# 37    NaN
# 39    NaN
# 40    1.0
# 41   11.2
# 42    3.4
# ..    ...
# 747   6.0
# 751   8.0
# 752  15.0
# 753   9.0
# 755   1.0
# 762   0.0
# 766   7.0
# 769   5.0
# 770   NaN
# 771  12.0
# 774   NaN
# 784   0.0
# 786  20.0
# 788   NaN
# 789  31.0
# 790   6.0
# 791   NaN
# 794   NaN
# 797   NaN
# 798   NaN
# 802   NaN
# 803  10.0
# 804   6.0
# 806   8.0
# 807   9.0
# 808   3.0
# 815   2.0
# 816   2.0
# 819   5.0
# 821   NaN
#
# [651 rows x 1 columns]

# %%
def mapper_func(val):
    if pd.isnull(val):
        return np.nan
    elif val < 3:
        return 'New: Less than 3 years at a company'
    elif val >= 3 and val <= 6:
        return 'Experienced: 3-6 years at a company'
    elif val >= 7 and val <= 10:
        return 'Established: 7-10 years at a company'
    else:
        return 'Veteran: 11 or more years at a company'

# %%
combined_updated['service_cat'] = extracted.applymap(mapper_func)

# %%
combined_updated['service_cat']
# Out:
# 3                                         NaN
# 4         Experienced: 3-6 years at a company
# 5        Established: 7-10 years at a company
# 6         Experienced: 3-6 years at a company
# 7         Experienced: 3-6 years at a company
# 8         Experienced: 3-6 years at a company
# 9         New: Less than 3 years at a company
# 10        New: Less than 3 years at a company
# 13     Veteran: 11 or more years at a company
# 14       Established: 7-10 years at a company
# 15     Veteran: 11 or more years at a company
# 16                                        NaN
# 17       Established: 7-10 years at a company
# 18                                        NaN
# 19                                        NaN
# 20                                        NaN
# 21                                        NaN
# 22        Experienced: 3-6 years at a company
# 23        New: Less than 3 years at a company
# 24       Established: 7-10 years at a company
# ...

# %%
combined_updated.head()
# Out:
#   Contributing Factors. Career Move - Private Sector   \
# 3                                                  -
# 4                       Career Move - Private Sector
# 5                                                  -
# 6                       Career Move - Private Sector
# 7                                                  -
#
#   Contributing Factors. Career Move - Public Sector   \
# 3                                                  -
# 4                                                  -
# 5                                                  -
# 6                                                  -
# 7                                                  -
#
#   Contributing Factors. Career Move - Self-employment  \
# 3                                                  -
# 4                                                  -
# 5                                                  -
# 6                                                  -
# ...

# %% [markdown]
# ## Initial Analysis

# %% [markdown]
# Recall that the `dissatisfied` column consists of True or False values. This column will be used in the initial analysis of the dataset.

# %%
combined_updated['dissatisfied'].value_counts(dropna = False)
# Out:
# False    403
# True     240
# NaN        8
# Name: dissatisfied, dtype: int64

# %% [markdown]
# All NaN values will be replaced with the value that occurs more frequently in the `dissatisfied` column.

# %%
dissatisfied_column_updated = combined_updated['dissatisfied'].fillna(False)

# %%
dissatisfied_column_updated.value_counts(dropna = False)
# Out:
# False    411
# True     240
# Name: dissatisfied, dtype: int64

# %%
combined_updated['dissatisfied'] = dissatisfied_column_updated

# %%
percent_dissatisfied = combined_updated.pivot_table('dissatisfied', 'service_cat')

# %%
percent_dissatisfied.plot(kind = 'bar')
